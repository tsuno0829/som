# %%
from datasets import make_datasets4som2
X = make_datasets4som2()
print(X.shape)
# Out:
# (9, 400, 2)

# %%
#import sys
#sys.path.append('../')

import glob
import numpy as np
import matplotlib.pyplot as plt

path = glob.glob('datasets4som2/*')
print(path)
fig, ax = plt.subplots(1,1,figsize=(8,6))
for p in path:
    X = np.loadtxt(p)
    ax.plot(X[0],X[1],label='{}'.format(p))
plt.legend()
plt.show()
# Out:
# ['datasets4som2/data9.txt', 'datasets4som2/data8.txt', 'datasets4som2/data1.txt', 'datasets4som2/data3.txt', 'datasets4som2/data2.txt', 'datasets4som2/data6.txt', 'datasets4som2/data7.txt', 'datasets4som2/data5.txt', 'datasets4som2/data4.txt']
