# %%
import sys
sys.path.append('../')
from models.SOM import SOM
from datasets.datasets import make_datasets4som2

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.animation as anim
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.cm import ScalarMappable

datasets_path = '../datasets/datasets4som2/*'
X = make_datasets4som2(datasets_path)
print(X.shape)

fig, ax = plt.subplots(1,1)
for i, x in enumerate(X):
    ax.plot(x[0],x[1],label='{}'.format(i))
plt.legend()
plt.show()
# Out:
# ['../datasets/datasets4som2/data9.txt', '../datasets/datasets4som2/data8.txt', '../datasets/datasets4som2/data1.txt', '../datasets/datasets4som2/data3.txt', '../datasets/datasets4som2/data2.txt', '../datasets/datasets4som2/data6.txt', '../datasets/datasets4som2/data7.txt', '../datasets/datasets4som2/data5.txt', '../datasets/datasets4som2/data4.txt']
# (9, 400, 2)
